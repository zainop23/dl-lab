# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Create image with rectangle
img = np.ones((300, 300, 3), dtype=np.uint8) * 255
cv2.rectangle(img, (100, 100), (200, 200), (255, 0, 0), 2)

h, w = img.shape[:2]
center = (w // 2, h // 2)

# Rotation
angle = 45
rot_matrix = cv2.getRotationMatrix2D(center, angle, 1)
rotated = cv2.warpAffine(img, rot_matrix, (w, h))

# Translation
tx, ty = 50, 30
trans_matrix = np.float32([[1, 0, tx], [0, 1, ty]])
translated = cv2.warpAffine(img, trans_matrix, (w, h))

# Combined (rotate + translate)
rot_matrix[0, 2] += tx
rot_matrix[1, 2] += ty
combined = cv2.warpAffine(img, rot_matrix, (w, h))

# Display
fig, ax = plt.subplots(2, 2, figsize=(10, 8))

ax[0, 0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
ax[0, 0].set_title("Original")

ax[0, 1].imshow(cv2.cvtColor(rotated, cv2.COLOR_BGR2RGB))
ax[0, 1].set_title("Rotated")

ax[1, 0].imshow(cv2.cvtColor(translated, cv2.COLOR_BGR2RGB))
ax[1, 0].set_title("Translated")

ax[1, 1].imshow(cv2.cvtColor(combined, cv2.COLOR_BGR2RGB))
ax[1, 1].set_title("Combined")

for a in ax.ravel():
    a.axis('off')

plt.tight_layout()
plt.show()

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-macosx_14_0_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=2 in /Users/anwerbasha/anaconda3/envs/ml-lab/lib/python3.11/site-packages (from opencv-python) (2.3.1)
# Downloading opencv_python-4.13.0.92-cp37-abi3-macosx_14_0_x86_64.whl (32.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.6/32.6 MB 3.7 MB/s  0:00:08m0:00:0100:01
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92
# Note: you may need to restart the kernel to use updated packages.
